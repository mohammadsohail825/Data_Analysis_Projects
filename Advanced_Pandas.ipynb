# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadsohail825/Project_prectic/blob/main/Advanced_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Creating & Reading CSV files

# %%
import pandas as pd

# %%
plears = pd.DataFrame({'Name':['Sehwag','Schin','Inzimam','A.B.Devilear','Yuvraj','Dhoni','Irfan','Murlidharan','Shoeb','Machgrath','Zahir'],
                       'Role':['Batsman','Batsman','Batsman','Batsman','Allrounder','WC.Batsman','Allrounder','Spinner','Fastboller','Fastboller','Fastboller'],
                       'Age':[29,34, 32,25,24,26,21,33,28,31,30],
                       'Team':['Punj','Mumbai','KKR','RCB','Dehli','CSK','Hydrabad','Rajisthan','KKR','Pune','Mumbai']})

# %%
# data = pd.DataFrame({
#     'Name' : ['Ankit', 'Aishwarya', 'Sanket', 'Shivangi', 'Saiprasad', 'Rishika', 'Pratiksha'],
#     'Age' : [23, 21, 22, 21, 22, 21, 20],
#     'University' : ['BHU', 'JNU', 'DU', 'BHU', 'SPPU', 'SPPU', 'DU'],
# })

# %%
plears
# Out:
#             Name        Role  Age       Team
# 0         Sehwag     Batsman   29       Punj
# 1          Schin     Batsman   34     Mumbai
# 2        Inzimam     Batsman   32        KKR
# 3   A.B.Devilear     Batsman   25        RCB
# 4         Yuvraj  Allrounder   24      Dehli
# 5          Dhoni  WC.Batsman   26        CSK
# 6          Irfan  Allrounder   21   Hydrabad
# 7    Murlidharan     Spinner   33  Rajisthan
# 8          Shoeb  Fastboller   28        KKR
# 9      Machgrath  Fastboller   31       Pune
# 10         Zahir  Fastboller   30     Mumbai

# %%
# data.to_csv('students.csv')
plears.to_csv('team.csv', index = False)

# %% [markdown]
# # Uploading Datasets

# %%
team = pd.read_csv('/content/team.csv')

# %%
team.head()
# Out:
#            Name        Role  Age    Team
# 0        Sehwag     Batsman   29    Punj
# 1         Schin     Batsman   34  Mumbai
# 2       Inzimam     Batsman   32     KKR
# 3  A.B.Devilear     Batsman   25     RCB
# 4        Yuvraj  Allrounder   24   Dehli

# %%
team
# Out:
#             Name  Age       Team
# 0         Sehwag   29       Punj
# 1          Schin   34     Mumbai
# 2        Inzimam   32        KKR
# 3   A.B.Devilear   25        RCB
# 4         Yuvraj   24      Dehli
# 5          Dhoni   26        CSK
# 6          Irfan   21   Hydrabad
# 7    Murlidharan   33  Rajisthan
# 8          Shoeb   28        KKR
# 9      Machgrath   31       Pune
# 10         Zahir   30     Mumbai

# %% [markdown]
# # Groupby Function

# %%
grouped = team.groupby('Role')

bat = grouped.get_group('Batsman')
bol = grouped.get_group('Fastboller')
all = grouped.get_group('Allrounder')
wc = grouped.get_group('WC.Batsman')

# %%
bat
# find batsman
# Out:
#            Name     Role  Age    Team
# 0        Sehwag  Batsman   29    Punj
# 1         Schin  Batsman   34  Mumbai
# 2       Inzimam  Batsman   32     KKR
# 3  A.B.Devilear  Batsman   25     RCB

# %%
all['Age'].mean()
# Out:
# 22.5

# %%
all
# Out:
#      Name        Role  Age      Team
# 4  Yuvraj  Allrounder   24     Dehli
# 6   Irfan  Allrounder   21  Hydrabad

# %%
bol
# Out:
#          Name        Role  Age    Team
# 8       Shoeb  Fastboller   28     KKR
# 9   Machgrath  Fastboller   31    Pune
# 10      Zahir  Fastboller   30  Mumbai

# %% [markdown]
# # Top Commands
#
# Creating New, Renaming & Droping Columns.
#
# Apply Method, Sort Index, Sort Values.

# %%
team
# Out:
#             Name        Role  Age       Team
# 0         Sehwag     Batsman   29       Punj
# 1          Schin     Batsman   34     Mumbai
# 2        Inzimam     Batsman   32        KKR
# 3   A.B.Devilear     Batsman   25        RCB
# 4         Yuvraj  Allrounder   24      Dehli
# 5          Dhoni  WC.Batsman   26        CSK
# 6          Irfan  Allrounder   21   Hydrabad
# 7    Murlidharan     Spinner   33  Rajisthan
# 8          Shoeb  Fastboller   28        KKR
# 9      Machgrath  Fastboller   31       Pune
# 10         Zahir  Fastboller   30     Mumbai

# %% [markdown]
# **Creating New Columns**

# %%
# Creating New Columns
team['FROM'] = ['India','India','Pakistan','South Africa','India','India','India','Shrilanka','Pakistan','Austrelia','India']

# %%
team
# Out:
#             NAME        ROLE  AGE  FRANCHISE NATIONAL TEAM
# 0         Sehwag     Batsman   29       Punj         India
# 1          Schin     Batsman   34     Mumbai         India
# 2        Inzimam     Batsman   32        KKR      Pakistan
# 3   A.B.Devilear     Batsman   25        RCB  South Africa
# 4         Yuvraj  Allrounder   24      Dehli         India
# 5          Dhoni  WC.Batsman   26        CSK         India
# 6          Irfan  Allrounder   21   Hydrabad         India
# 7    Murlidharan     Spinner   33  Rajisthan     Shrilanka
# 8          Shoeb  Fastboller   28        KKR      Pakistan
# 9      Machgrath  Fastboller   31       Pune     Austrelia
# 10         Zahir  Fastboller   30     Mumbai         India

# %% [markdown]
# **Renaming Columns**

# %%
team.columns = ['NAME', 'ROLE','AGE','FRANCHISE','NATIONAL']

# %%
team
# Out:
#             NAME        ROLE  AGE  FRANCHISE      NATIONAL
# 0         Sehwag     Batsman   29       Punj         India
# 1          Schin     Batsman   34     Mumbai         India
# 2        Inzimam     Batsman   32        KKR      Pakistan
# 3   A.B.Devilear     Batsman   25        RCB  South Africa
# 4         Yuvraj  Allrounder   24      Dehli         India
# 5          Dhoni  WC.Batsman   26        CSK         India
# 6          Irfan  Allrounder   21   Hydrabad         India
# 7    Murlidharan     Spinner   33  Rajisthan     Shrilanka
# 8          Shoeb  Fastboller   28        KKR      Pakistan
# 9      Machgrath  Fastboller   31       Pune     Austrelia
# 10         Zahir  Fastboller   30     Mumbai         India

# %% [markdown]
# **Droping Columns**

# %%
team.drop(['AGE'], axis = 1)           # Temporary Droping Syntax
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL
# 0         Sehwag     Batsman       Punj         India
# 1          Schin     Batsman     Mumbai         India
# 2        Inzimam     Batsman        KKR      Pakistan
# 3   A.B.Devilear     Batsman        RCB  South Africa
# 4         Yuvraj  Allrounder      Dehli         India
# 5          Dhoni  WC.Batsman        CSK         India
# 6          Irfan  Allrounder   Hydrabad         India
# 7    Murlidharan     Spinner  Rajisthan     Shrilanka
# 8          Shoeb  Fastboller        KKR      Pakistan
# 9      Machgrath  Fastboller       Pune     Austrelia
# 10         Zahir  Fastboller     Mumbai         India

# %%
team
# Out:
#             NAME        ROLE  AGE  FRANCHISE      NATIONAL
# 0         Sehwag     Batsman   29       Punj         India
# 1          Schin     Batsman   34     Mumbai         India
# 2        Inzimam     Batsman   32        KKR      Pakistan
# 3   A.B.Devilear     Batsman   25        RCB  South Africa
# 4         Yuvraj  Allrounder   24      Dehli         India
# 5          Dhoni  WC.Batsman   26        CSK         India
# 6          Irfan  Allrounder   21   Hydrabad         India
# 7    Murlidharan     Spinner   33  Rajisthan     Shrilanka
# 8          Shoeb  Fastboller   28        KKR      Pakistan
# 9      Machgrath  Fastboller   31       Pune     Austrelia
# 10         Zahir  Fastboller   30     Mumbai         India

# %%
team.drop(['AGE'], axis = 1, inplace = True)           # Permanent Droping Syntax

# %%
team
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL
# 0         Sehwag     Batsman       Punj         India
# 1          Schin     Batsman     Mumbai         India
# 2        Inzimam     Batsman        KKR      Pakistan
# 3   A.B.Devilear     Batsman        RCB  South Africa
# 4         Yuvraj  Allrounder      Dehli         India
# 5          Dhoni  WC.Batsman        CSK         India
# 6          Irfan  Allrounder   Hydrabad         India
# 7    Murlidharan     Spinner  Rajisthan     Shrilanka
# 8          Shoeb  Fastboller        KKR      Pakistan
# 9      Machgrath  Fastboller       Pune     Austrelia
# 10         Zahir  Fastboller     Mumbai         India

# %% [markdown]
# **Apply Method**

# %%
# Creating Marks Column

team['Runs'] = [825, 625, 725, 536, 598, 425, 398, 76, 85, 40, 99]

# %%
team
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL   AVERAGE  Runs
# 0         Sehwag     Batsman       Punj         India  0.477431   825
# 1          Schin     Batsman     Mumbai         India  0.361690   625
# 2        Inzimam     Batsman        KKR      Pakistan  0.419560   725
# 3   A.B.Devilear     Batsman        RCB  South Africa  0.310185   536
# 4         Yuvraj  Allrounder      Dehli         India  0.346065   598
# 5          Dhoni  WC.Batsman        CSK         India  0.245949   425
# 6          Irfan  Allrounder   Hydrabad         India  0.230324   398
# 7    Murlidharan     Spinner  Rajisthan     Shrilanka  0.043981    76
# 8          Shoeb  Fastboller        KKR      Pakistan  0.049190    85
# 9      Machgrath  Fastboller       Pune     Austrelia  0.023148    40
# 10         Zahir  Fastboller     Mumbai         India  0.057292    99

# %%
team.drop(['Runs','AVERAGE'], axis = 1, inplace = True)

# %%
team['Runs'] = [825, 625, 725, 536, 598, 425, 398, 76, 85, 40, 99]

# %%
team
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL  Runs
# 0         Sehwag     Batsman       Punj         India   825
# 1          Schin     Batsman     Mumbai         India   625
# 2        Inzimam     Batsman        KKR      Pakistan   725
# 3   A.B.Devilear     Batsman        RCB  South Africa   536
# 4         Yuvraj  Allrounder      Dehli         India   598
# 5          Dhoni  WC.Batsman        CSK         India   425
# 6          Irfan  Allrounder   Hydrabad         India   398
# 7    Murlidharan     Spinner  Rajisthan     Shrilanka    76
# 8          Shoeb  Fastboller        KKR      Pakistan    85
# 9      Machgrath  Fastboller       Pune     Austrelia    40
# 10         Zahir  Fastboller     Mumbai         India    99

# %%
# Apply Method

team['Runs'] = team['Runs'].apply(lambda x: round(x / 12, 2))

# %%
team['Runs'] = team['Runs'].apply(lambda x: round(x * 12, 2)) # IF lambda funtion run two times

# %%
team
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL   Runs
# 0         Sehwag     Batsman       Punj         India  68.76
# 1          Schin     Batsman     Mumbai         India  52.08
# 2        Inzimam     Batsman        KKR      Pakistan  60.36
# 3   A.B.Devilear     Batsman        RCB  South Africa  44.64
# 4         Yuvraj  Allrounder      Dehli         India  49.80
# 5          Dhoni  WC.Batsman        CSK         India  35.40
# 6          Irfan  Allrounder   Hydrabad         India  33.12
# 7    Murlidharan     Spinner  Rajisthan     Shrilanka   6.36
# 8          Shoeb  Fastboller        KKR      Pakistan   7.08
# 9      Machgrath  Fastboller       Pune     Austrelia   3.36
# 10         Zahir  Fastboller     Mumbai         India   8.28

# %%
# Renaming Column

team.columns = ['NAME', 'ROLE','FRANCHISE','NATIONAL','AVERAGE']

# %%
team
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL  AVERAGE
# 0         Sehwag     Batsman       Punj         India    68.76
# 1          Schin     Batsman     Mumbai         India    52.08
# 2        Inzimam     Batsman        KKR      Pakistan    60.36
# 3   A.B.Devilear     Batsman        RCB  South Africa    44.64
# 4         Yuvraj  Allrounder      Dehli         India    49.80
# 5          Dhoni  WC.Batsman        CSK         India    35.40
# 6          Irfan  Allrounder   Hydrabad         India    33.12
# 7    Murlidharan     Spinner  Rajisthan     Shrilanka     6.36
# 8          Shoeb  Fastboller        KKR      Pakistan     7.08
# 9      Machgrath  Fastboller       Pune     Austrelia     3.36
# 10         Zahir  Fastboller     Mumbai         India     8.28

# %% [markdown]
# **Sort Index**

# %%
team.index = [10,11,9,7,1,6,8,5,4,3,2]          # Assigning Index

# %%
team
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL  AVERAGE
# 10        Sehwag     Batsman       Punj         India    68.76
# 11         Schin     Batsman     Mumbai         India    52.08
# 9        Inzimam     Batsman        KKR      Pakistan    60.36
# 7   A.B.Devilear     Batsman        RCB  South Africa    44.64
# 1         Yuvraj  Allrounder      Dehli         India    49.80
# 6          Dhoni  WC.Batsman        CSK         India    35.40
# 8          Irfan  Allrounder   Hydrabad         India    33.12
# 5    Murlidharan     Spinner  Rajisthan     Shrilanka     6.36
# 4          Shoeb  Fastboller        KKR      Pakistan     7.08
# 3      Machgrath  Fastboller       Pune     Austrelia     3.36
# 2          Zahir  Fastboller     Mumbai         India     8.28

# %%
team.sort_index()                      # Default Statement : Ascending = True
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL  AVERAGE
# 1         Yuvraj  Allrounder      Dehli         India    49.80
# 2          Zahir  Fastboller     Mumbai         India     8.28
# 3      Machgrath  Fastboller       Pune     Austrelia     3.36
# 4          Shoeb  Fastboller        KKR      Pakistan     7.08
# 5    Murlidharan     Spinner  Rajisthan     Shrilanka     6.36
# 6          Dhoni  WC.Batsman        CSK         India    35.40
# 7   A.B.Devilear     Batsman        RCB  South Africa    44.64
# 8          Irfan  Allrounder   Hydrabad         India    33.12
# 9        Inzimam     Batsman        KKR      Pakistan    60.36
# 10        Sehwag     Batsman       Punj         India    68.76
# 11         Schin     Batsman     Mumbai         India    52.08

# %%
team.sort_values(by = "AVERAGE", ascending= False) #sort acording to columns
# Out:
#             NAME        ROLE  FRANCHISE      NATIONAL  AVERAGE
# 10        Sehwag     Batsman       Punj         India    68.76
# 9        Inzimam     Batsman        KKR      Pakistan    60.36
# 11         Schin     Batsman     Mumbai         India    52.08
# 1         Yuvraj  Allrounder      Dehli         India    49.80
# 7   A.B.Devilear     Batsman        RCB  South Africa    44.64
# 6          Dhoni  WC.Batsman        CSK         India    35.40
# 8          Irfan  Allrounder   Hydrabad         India    33.12
# 2          Zahir  Fastboller     Mumbai         India     8.28
# 4          Shoeb  Fastboller        KKR      Pakistan     7.08
# 5    Murlidharan     Spinner  Rajisthan     Shrilanka     6.36
# 3      Machgrath  Fastboller       Pune     Austrelia     3.36
