# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadsohail825/Project_prectic/blob/main/Pandas_Assignment_Day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
a = pd.Series([ 100, 200, 300, 400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
element_300 = a[2]
print(element_300)
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
a
# series a indexing o to 3
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c', 'a', 'b', 'd']
a
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
a['d']
# value_d = a['d'] # we also this formate to given variable for finding indexing
# print(value_d)
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
sort_values = a.sort_index()
print(sort_values)
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
b = pd.Series([800,450,100],index=['e','f','g'])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
append_b = pd.concat([a,b]) # if append function given error than we can use concat funtion
print(append_b)
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %%
#print a again after appending b into it
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
a = a.sort_values(ascending=False)
print(a)
# Out:
# d    400
# b    300
# a    200
# c    100
# dtype: int64

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
df = a.to_frame()
df
# Out:
#      0
# d  400
# b  300
# a  200
# c  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
df.shape # Implies datagrame has 4 row and 1 column.
# Out:
# (4, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.

a
# Out:
# d    400
# b    300
# a    200
# c    100
# dtype: int64

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
df.head() #print head
# Out:
#      0
# d  400
# b  300
# a  200
# c  100

# %%
df.tail(2) #print tail
# Out:
#      0
# a  200
# c  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.columns = ['points']
df
# Out:
#    points
# d     400
# b     300
# a     200
# c     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

fruits = np.random.choice(['orange','mango','apple'],7)
print(fruits)
# Out:
# ['orange' 'orange' 'apple' 'orange' 'apple' 'apple' 'mango']

# %%
#Create series fruits out of fruits array

fruits = pd.Series(fruits)
print(fruits)
# Out:
# 0     mango
# 1     apple
# 2     apple
# 3     mango
# 4     mango
# 5    orange
# 6     apple
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruit_df = pd.DataFrame(fruits)

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
fruit_df.columns = ['Fruits']
fruit_df
# Out:
#    Fruits
# 0  orange
# 1  orange
# 2   apple
# 3  orange
# 4   apple
# 5   apple
# 6   mango

# %%
fruit_df.head()
# Out:
#    Fruits
# 0  orange
# 1  orange
# 2   apple
# 3  orange
# 4   apple

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
d1 = pd.DataFrame({'City':['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],'Temperature' : [15, 22, 20, 26,-2]})

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          City  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
d1.shape # There are 5 rows and 2 columns
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
#Set city = d1['city']
city = d1['City']

# %%
d1.columns = ['city','Temperature']
d1
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
type(city)
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: City, dtype: object
# pandas.core.series.Series

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
d2 = pd.DataFrame({'city':['Bengalaru','Coimbatore','Srirangam','Pondicherry'], 'Temperature':[24,35,36,39]})
d2
# Out:
#           city  Temperature
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# print the shape of this dataframe

# %%
d2.shape
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
d3 = pd.concat([d1,d2],axis=0)
d3
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
d3[d3['Temperature']<=20]['city'] #There are 3 cities where temperature less than 20
# Out:
# 0    Chandigarh
# 2        Kanpur
# 4        Manali
# Name: city, dtype: object

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
d3[d3['Temperature']>=35]['city']
# Out:
# 1     Coimbatore
# 2      Srirangam
# 3    Pondicherry
# Name: city, dtype: object

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here

def is_ut(x):
  union_territories = ['Chandigarh','Pondicherry','Delhi']
  return x in union_territories
  d3['is_ut'] = d3['city'].apply('is_ut')

# %%
# print d3
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 0    Bengalaru           24  False
# 1   Coimbatore           35  False
# 2    Srirangam           36  False
# 3  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here
def c_to_f(x):
  return (x*9/5)+32

# %%
# check function c_to_f(10)
c_to_f(10)
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'
d3['temp_farehiet'] = d3['Temperature'].apply(c_to_f)

# %%
d3
# Out:
#           city  Temperature  is_ut  temp_farehiet
# 0   Chandigarh           15   True           59.0
# 1        Delhi           22   True           71.6
# 2       Kanpur           20  False           68.0
# 3      Chennai           26  False           78.8
# 4       Manali           -2  False           28.4
# 0    Bengalaru           24  False           75.2
# 1   Coimbatore           35  False           95.0
# 2    Srirangam           36  False           96.8
# 3  Pondicherry           39   True          102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
union_territories = ['Chandigarh','Pondicherry','Delhi']
subset_d1 = d1[d1['city'].isin(union_territories)]

# %%
subset_d1 # Union Territories in subset d1
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
temp_d1 = d1[d1['Temperature']*9/5 +32 > 90]
print(temp_d1) # in d1 subset all city temperature are less than 90 f
# Out:
# Empty DataFrame
# Columns: [city, Temperature]
# Index: []

# %%
d1_fehn = d1['Temperature'].apply(c_to_f)
print(d1_fehn) # showing d1 subset temperature in farenhiet.
# Out:
# 0    59.0
# 1    71.6
# 2    68.0
# 3    78.8
# 4    28.4
# Name: Temperature, dtype: float64

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
d1.head(3)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
d1.iloc[: ,-2:]
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

data = {'Name':['Aqib','Basid','Salman','Jishan','Daud'],
        'City':['Abu','Dhabi','UAE','KSA','Ind'],
        'Salary':[2500,3500,1500,6000,7500]}
df = pd.DataFrame(data)
df
# Out:
#      Name   City  Salary
# 0    Aqib    Abu    2500
# 1   Basid  Dhabi    3500
# 2  Salman    UAE    1500
# 3  Jishan    KSA    6000
# 4    Daud    Ind    7500

# %%
# Use Groupby of single column with aggregate sum()
df.groupby('City')['Salary'].sum()
# Out:
# City
# Abu      2500
# Dhabi    3500
# Ind      7500
# KSA      6000
# UAE      1500
# Name: Salary, dtype: int64

# %%
# Use Groupby of single column with aggregate count()
df.groupby('City')['Salary'].count()
# Out:
# City
# Abu      1
# Dhabi    1
# Ind      1
# KSA      1
# UAE      1
# Name: Salary, dtype: int64

# %%
# Use Groupby of single column with aggregate min() and max()
df.groupby('City')['Salary'].agg(['min', 'max'])
# Out:
#         min   max
# City
# Abu    2500  2500
# Dhabi  3500  3500
# Ind    7500  7500
# KSA    6000  6000
# UAE    1500  1500

# %%
# Use Groupby of any 2 columns with aggregate mean()
df.groupby(['Name','City'])['Salary'].mean()
# Out:
# Name    City
# Aqib    Abu      2500.0
# Basid   Dhabi    3500.0
# Daud    Ind      7500.0
# Jishan  KSA      6000.0
# Salman  UAE      1500.0
# Name: Salary, dtype: float64

# %%
# Use Groupby of any 2 columns with aggregate min() and max()
df.groupby(['Name','City'])['Salary'].agg(['min','max'])
# Out:
#                min   max
# Name   City
# Aqib   Abu    2500  2500
# Basid  Dhabi  3500  3500
# Daud   Ind    7500  7500
# Jishan KSA    6000  6000
# Salman UAE    1500  1500

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
a = pd.date_range(start='01-01-2020' , end = '04-01-2021')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31', '2021-01-01', '2021-01-02',
#                '2021-01-03', '2021-01-04'],
#               dtype='datetime64[ns]', length=370, freq='D')

# %% [markdown]
# What is the len of a?

# %%
len(a)
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex
